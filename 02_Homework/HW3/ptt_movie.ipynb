# %% [markdown]
# ## ptt_movie版資料下載

# %%
# !pip install beautifulsoup4
from bs4 import BeautifulSoup 
import requests
import json
import csv
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.2.1)

# %%
response = requests.get("https://www.ptt.cc/bbs/movie/index9507.html")
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())  #輸出排版後的HTML內容
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    看板 movie 文章列表 - 批踢踢實業坊
#   </title>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/movie/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      movie
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="main-container">
#    <div id="action-bar-container">
#     <div class="action-bar">
#      <div class="btn-group btn-group-dir">
#       <a class="btn selected" href="/bbs/movie/index.html">
#        看板
#       </a>
#       <a class="btn" href="/man/movie/index.html">
#        精華區
#       </a>
#      </div>
#      <div class="btn-group btn-group-paging">
#       <a class="btn wide" href="/bbs/movie/index1.html">
#        最舊
#       </a>
#       <a class="btn wide" href="/bbs/movie/index9506.html">
#        ‹ 上頁
#       </a>
#       <a class="btn wide disabled">
#        下頁 ›
#       </a>
#       <a class="btn wide" href="/bbs/movie/index.html">
#        最新
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="r-list-container action-bar-margin bbs-screen">
#     <div class="search-bar">
#      <form action="search" id="search-bar" type="get">
#       <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
#      </form>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        69
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1667393942.A.1E6.html">
#        [討論] 阿凡達：水之道 完整預告出爐
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        yueh1001
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E9%98%BF%E5%87%A1%E9%81%94%EF%BC%9A%E6%B0%B4%E4%B9%8B%E9%81%93+%E5%AE%8C%E6%95%B4%E9%A0%90%E5%91%8A%E5%87%BA%E7%88%90">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Ayueh1001">
#           搜尋看板內 yueh1001 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/02
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        75
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1667397123.A.69A.html">
#        [新聞] 丹尼爾雷德克里夫認為站出來反對 JK 羅琳
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        chirex
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E4%B8%B9%E5%B0%BC%E7%88%BE%E9%9B%B7%E5%BE%B7%E5%85%8B%E9%87%8C%E5%A4%AB%E8%AA%8D%E7%82%BA%E7%AB%99%E5%87%BA%E4%BE%86%E5%8F%8D%E5%B0%8D+JK+%E7%BE%85%E7%90%B3">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Achirex">
#           搜尋看板內 chirex 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/02
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1667399051.A.84C.html">
#        Re: [請益] 有沒有推薦的香港警匪片
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        chulin
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E8%AB%8B%E7%9B%8A%5D+%E6%9C%89%E6%B2%92%E6%9C%89%E6%8E%A8%E8%96%A6%E7%9A%84%E9%A6%99%E6%B8%AF%E8%AD%A6%E5%8C%AA%E7%89%87">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Achulin">
#           搜尋看板內 chulin 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/02
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        2
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1667400697.A.969.html">
#        [新聞] 汪達兒子加盟《混沌女巫團》成為同性戀
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        hp8232
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%
的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/02
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        8
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1667404988.A.AB7.html">
#        [普雷] 流麻溝十五號：看完反而省思更多
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        daieason0806
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E6%99%AE%E9%9B%B7%5D+%E6%B5%81%E9%BA%BB%E6%BA%9D%E5%8D%81%E4%BA%94%E8%99%9F%EF%BC%9A%E7%9C%8B%E5%AE%8C%E5%8F%8D%E8%80%8C%E7%9C%81%E6%80%9D%E6%9B%B4%E5%A4%9A">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Adaieason0806">
#           搜尋看板內 daieason0806 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       (本文已被刪除) [hstrxgfcg216]
#      </div>
#      <div class="meta">
#       <div class="author">
#        -
#       </div>
#       <div class="article-menu">
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1667410248.A.AEF.html">
#        [討論] 「有雷」西線無戰事衣服問題
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        hstrxgfcg216
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E3%80%8C%E6%9C%89%E9%9B%B7%E3%80%8D%E8%A5%BF%E7%B7%9A%E7%84%A1%E6%88%B0%E4%BA%8B%E8%A1%A3%E6%9C%8D%E5%95%8F%E9%A1%8C">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Ahstrxgfcg216">
#           搜尋看板內 hstrxgfcg216 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1667410524.A.EB6.html">
#        [普雷] 流麻溝十五號
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        werttrew
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E6%99%AE%E9%9B%B7%5D+%E6%B5%81%E9%BA%BB%E6%BA%9D%E5%8D%81%E4%BA%94%E8%99%9F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Awerttrew">
#           搜尋看板內 werttrew 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        2
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1667412136.A.E0D.html">
#        [討論] Michael J. Fox是很勇敢的演員吧？
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        gamesame7711
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+Michael+J.+Fox%E6%98%AF%E5%BE%88%E5%8B%87%E6%95%A2%E7%9A%84%E6%BC%94%E5%93%A1%E5%90%A7%EF%BC%9F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Agamesame7711">
#           搜尋看板內 gamesame7711 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-list-sep">
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1630756788.A.1FE.html">
#        [公告] 電影板板規 2021/9/4
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        ckshchen
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E9%9B%BB%E5%BD%B1%E6%9D%BF%E6%9D%BF%E8%A6%8F+2021%2F9%2F4">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Ackshchen">
#           搜尋看板內 ckshchen 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        9/04
#       </div>
#       <div class="mark">
#        !
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        2
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1636002497.A.7EC.html">
#        [宣導] 請注意防雷 / 分類
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        lgng66133
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E5%AE%A3%E5%B0%8E%5D+%E8%AB%8B%E6%B3%A8%E6%84%8F%E9%98%B2%E9%9B%B7+%2F+%E5%88%86%E9%A1%9E">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Algng66133">
#           搜尋看板內 lgng66133 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/04
#       </div>
#       <div class="mark">
#        M
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        71
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/movie/M.1664272810.A.ED2.html">
#        [情報] 2022 第59屆金馬獎 入圍名單&amp;入圍統計
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        lgng66133
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/movie/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+2022+%E7%AC%AC59%E5%B1%86%E9%87%91%E9%A6%AC%E7%8D%8E+%E5%85%A5%E5%9C%8D%E5%90%8D%E5%96%AE%26%E5%85%A5%E5%9C%8D%E7%B5%B1%E8%A8%88">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/movie/search?q=author%3Algng66133">
#           搜尋看板內 lgng66133 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        9/27
#       </div>
#       <div class="mark">
#        M
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.27/bbs.js">
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"763f866b9a2a7c41","version":"2022.10.3","r":1,"token":"515615eb5fab4c9b91a11e9bf529e6cf","si":100}' defer="" integrity="sha512-0ahDYl866UMhKuYcW078ScMalXqtFJggm7TmlUtp0UlD4eQk0Ixfnm5ykXKvGJNFjLMoortdseTfsRT8oCfgGA==" src="https://static.cloudflareinsights.com/beacon.min.js/vaafb692b2aea4879b33c060e79fe94621666317369993">
#   </script>
#  </body>
# </html>

# %%
#抓取標題（含網址）、日期及作者
title = soup.select("div.title a")
date = soup.select("div.date")
author = soup.select("div.author")
print(title)
# Out:
# [<a href="/bbs/movie/M.1667393942.A.1E6.html">[討論] 阿凡達：水之道 完整預告出爐</a>, <a href="/bbs/movie/M.1667397123.A.69A.html">[新聞] 丹尼爾雷德克里夫認為站出來反對 JK 羅琳</a>, <a href="/bbs/movie/M.1667399051.A.84C.html">Re: [請益] 有沒有推薦的香港警匪片</a>, <a href="/bbs/movie/M.1667400697.A.969.html">[新聞] 汪達兒子加盟《混沌女巫團》成為同性戀</a>, <a href="/bbs/movie/M.1667402594.A.466.html">[新聞] 《聖誕夜驚魂》掛名提姆波頓 導演坦言不</a>, <a href="/bbs/movie/M.1667403032.A.A40.html">Re: [討論] 有比搶救雷恩大兵 厄本還黑的角色嗎?</a>, <a href="/bbs/movie/M.1667403272.A.005.html">[新聞] 原作者證實《BJ單身日記》第四集正醞釀中</a>, <a href="/bbs/movie/M.1667403808.A.304.html">[好雷] 罪後真相二刷心得</a>, <a href="/bbs/movie/M.1667403916.A.E25.html">[討論] 哈利波特電影算是靠原著紅嗎？</a>, <a href="/bbs/movie/M.1667403921.A.096.html">[討論] 《酷愛電影的龐波小姐》已上架動畫瘋</a>, <a href="/bbs/movie/M.1667404988.A.AB7.html">[普雷] 流麻溝十五號：看完反而省思更多</a>, <a href="/bbs/movie/M.1667410248.A.AEF.html">[討論] 「有雷」西線無戰事衣服問題</a>, <a href="/bbs/movie/M.1667410524.A.EB6.html">[普雷] 流麻溝十五號</a>, <a href="/bbs/movie/M.1667412136.A.E0D.html">[討論] Michael J. Fox是很勇敢的演員吧？</a>, <a href="/bbs/movie/M.1630756788.A.1FE.html">[公告] 電影板板規 2021/9/4</a>, <a href="/bbs/movie/M.1636002497.A.7EC.html">[宣導] 請注意防雷 / 分類</a>, <a href="/bbs/movie/M.1664272810.A.ED2.html">[情報] 2022 第59屆金馬獎 入圍名單&amp;入圍統計</a>]

# %%
#存為json檔案
movie_pdict = []
for i in range(len(title)):
    movie_pdict.append({"wabsite":title[i]["href"],"title":title[i].text,"date":date[i].text,"author":author[i].text})
movie_dict = {"movie":movie_pdict}

with open("movie_dict.json", "w") as f:
    json.dump(movie_dict, f)

# %%
#存為csv檔案
movie_list = []
for i in range(len(title)):
    movie_list.append([title[i]["href"],title[i].text,date[i].text,author[i].text])

with open('movie_list.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(movie_list)
