# %%
#!pip install jieba 
import jieba
import jieba.analyse
import pandas as pd
import numpy
from collections import Counter

# %%
import json
import csv
with open('/Users/anderson/Desktop/Data Science/GitHub/PL-Repo/02_Homework/HW3/gulong_leeknife_sort.csv') as f:
    temp = csv.reader(f)
temp

# %%
temp[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/k_/2r9gfk5j0fbc0l7wptv_v2jc0000gn/T/ipykernel_20316/4069538798.py in <module>
# ----> 1 temp[1]
#
# TypeError: '_csv.reader' object is not subscriptable

# %%
#讀取json
import json
with open('gulong_leeknife.json') as f:
    temp = json.load(f)

orgdata = ""
for i in range(1,len(temp)+1):
    orgdata = orgdata + temp[f"{i}"]
print(orgdata[0:30])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/k_/2r9gfk5j0fbc0l7wptv_v2jc0000gn/T/ipykernel_20316/99427821.py in <module>
#       6 orgdata = ""
#       7 for i in range(1,len(temp)+1):
# ----> 8     orgdata = orgdata + temp[f"{i}"]
#       9 print(orgdata[0:30])
#
# KeyError: '20'

# %%
len(temp.dtype)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/k_/2r9gfk5j0fbc0l7wptv_v2jc0000gn/T/ipykernel_27861/2727010124.py in <module>
# ----> 1 len(temp.dtype)
#
# AttributeError: 'dict' object has no attribute 'dtype'

# %%
jieba.set_dictionary('/Users/anderson/Desktop/Data Science/dict.txt.big')

# %%
#!pip install wordcloud
import plotly.express as px
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import jieba
import jieba.analyse
from collections import Counter # 次數統計

# %%
dictfile = "/Users/anderson/Desktop/Data Science/dict.txt.big"  # 字典檔
stopfile = "./stopwords_knife.txt"  # stopwords
fontpath = "/Users/anderson/Library/Group Containers/UBF8T346G9.Office/FontCache/4/CloudFonts/TTC/82731638364.ttc"  # 字型檔

#mdfile = test_tt[0]
pngfile = "./vg_knife.webp"  # 剛才下載存的底圖

alice_mask = np.array(Image.open(pngfile))

jieba.set_dictionary(dictfile)
jieba.analyse.set_stop_words(stopfile)

#text = open(mdfile,"r",encoding="utf-8").read()

tags = jieba.analyse.extract_tags(orgdata, topK=125)

seg_list = jieba.lcut(orgdata, cut_all=False)
dictionary = Counter(seg_list)

freq = {}
for ele in dictionary:
    if ele in tags:
        freq[ele] = dictionary[ele]
print(freq) # 計算出現的次數

wordcloud = WordCloud(background_color="white", mask=alice_mask, contour_color='steelblue', font_path= fontpath).generate_from_frequencies(freq)
plt.figure(figsize=(20,20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Building prefix dict from /Users/anderson/Desktop/Data Science/dict.txt.big ...
# Loading model from cache /var/folders/k_/2r9gfk5j0fbc0l7wptv_v2jc0000gn/T/jieba.u52e16fc3ddadd0bb6f0fd9b070d121de.cache
# Loading model cost 1.151 seconds.
# Prefix dict has been built successfully.
# {'彭連虎': 15, '沙通天': 12, '卻是': 15, '裘千仞': 18, '兩人': 11, '女兒': 6, '性命': 11, '不知': 15, '心想': 18, '這時': 12, '低聲': 6, '過了': 7, '洪七公': 14, '說道': 30, '全真': 7, '動手': 6, '給你': 5, '全真諸': 8, '自己': 24, '地下': 13, '老頑童': 9, '一聲': 23, '怒道': 6, '還是': 7, '烏雲': 5, '丘處機': 12, '當下': 15, '眾人': 15, '王處一': 8, '哪裏': 14, '當真': 12, '過去': 10, '舉起': 6, '靈智上人': 6, '梁子翁': 7, '敵人': 10, '功夫': 8, '此時': 8, '下來': 5, '武功': 12, '判官筆': 6, '下去': 12, '避開': 6, '左手': 8, '身旁': 13, '聽得': 7, '原來': 17, '適才': 5, '竹棒': 6, '小妖女': 7, '黃蓉叫': 6, '一時': 5, '聽到': 10, '一個': 16, '輕輕': 5, '一陣': 13, '濃霧': 5, '煙雨樓': 13, '他們': 9, '大霧': 8, '之中': 12, '之間': 5, '起來': 9, '黃老邪': 5, '全真教': 12, '報仇': 5, '這位': 6, '九陰真經': 7, '爹爹': 43, '經文': 10, '出來': 12, '島上': 14, '雖然': 6, '見到': 8, '這是': 6, '師父': 10, '老毒物': 9, '聲音': 14, '不見': 11, '爺爺': 36, '豈知': 5, '心中': 15, '一會': 5, '答應': 5, '紛紛': 5, '咱們': 8, '這場': 5, '官軍': 15, '官兵': 14, '給我': 5, '身上': 12, '豈能': 6, '臉上': 5, '過來': 5, '始終': 8, '這個': 8, '總是': 5, '之後': 7, '聽黃蓉': 11, '幾句': 7, '你們': 12, '兩名': 7, '創口': 6, '桃花島': 10, '鐵槍': 16, '問道': 9, '蒲團': 5, '黃蓉笑': 5, '朱聰': 6, '韓寶駒': 5, '南希仁': 9, '神像': 7, '這裏': 5, '小王爺': 13, '日後': 5, '晚輩': 5, '道士': 10, '許多': 5, '傻姑': 23, '傻姑道': 18, '歐陽': 12, '伯伯': 12, '或時': 6, '後來': 8, '六怪': 8}

# %%
alice_mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
#暫時貼
flat = [x for sublist in subdata_seg_list for x in sublist]
diction = Counter(flat)

# %%
#暫時貼
mask = np.array(Image.open("criminal.jpg"))
font = "C:\Windows\Fonts\MSJH.TTC"

# %%
#暫時貼
wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(diction)

# %%
#暫時貼
plt.figure(figsize=(20,20))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
print("test\ahaha")
# Out:
# testhaha
