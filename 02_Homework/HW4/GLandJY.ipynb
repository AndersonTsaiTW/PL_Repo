# %%
#!pip install jieba 
import jieba
import jieba.analyse
import pandas as pd
import numpy
from collections import Counter

# %%
#讀取古龍及金庸小說文字檔案
lee = pd.read_csv('/Users/anderson/Desktop/Data Science/GitHub/PL-Repo/02_Homework/HW3/gulong_leeknife_sort.csv')
cheros = pd.read_csv('/Users/anderson/Desktop/Data Science/GitHub/PL-Repo/02_Homework/HW3/jy_c_heroes_sort.csv')

# %%
lee_all = ""
for i in range(0,89):
    lee_all = lee_all + lee["text"][i]
len(lee_all)
# Out:
# 430329

# %%
#!pip install wordcloud
from wordcloud import WordCloud, STOPWORDS
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import jieba
import jieba.analyse
from collections import Counter # 次數統計

# %%
dictfile = "/Users/anderson/Desktop/Data Science/dict.txt.big"  # 字典檔
stopfile = "/Users/anderson/Desktop/Data Science/GitHub/PL-Repo/02_Homework/HW4/stopwords.txt"  # stopwords
fontpath = "/Users/anderson/Library/Group Containers/UBF8T346G9.Office/FontCache/4/CloudFonts/TTC/82731638364.ttc"  # 字型檔

#mdfile = test_tt[0]
pngfile = "./vg_knife.webp"  # 剛才下載存的底圖

alice_mask = np.array(Image.open(pngfile))

jieba.set_dictionary(dictfile)
jieba.analyse.set_stop_words(stopfile)

#text = open(mdfile,"r",encoding="utf-8").read()

tags = jieba.analyse.extract_tags(lee_all, topK=200)

seg_list = jieba.lcut(lee_all, cut_all=False)
dictionary = Counter(seg_list)

freq = {}
for ele in dictionary:
    if ele in tags:
        freq[ele] = dictionary[ele]
print(freq) # 計算出現的次數

wordcloud = WordCloud(background_color="white", mask=alice_mask, contour_color='steelblue', font_path= fontpath).generate_from_frequencies(freq)
plt.figure(figsize=(30,30))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Building prefix dict from /Users/anderson/Desktop/Data Science/dict.txt.big ...
# Loading model from cache /var/folders/k_/2r9gfk5j0fbc0l7wptv_v2jc0000gn/T/jieba.u52e16fc3ddadd0bb6f0fd9b070d121de.cache
# Loading model cost 1.079 seconds.
# Prefix dict has been built successfully.

# %%
dictfile = "/Users/anderson/Desktop/Data Science/dict.txt.big"  # 字典檔
stopfile = "/Users/anderson/Desktop/Data Science/GitHub/PL-Repo/02_Homework/HW4/stopwords.txt"  # stopwords
fontpath = "/Users/anderson/Library/Group Containers/UBF8T346G9.Office/FontCache/4/CloudFonts/TTC/82731638364.ttc"  # 字型檔

#mdfile = test_tt[0]
pngfile = "./vg_knife.webp"  # 剛才下載存的底圖

alice_mask = np.array(Image.open(pngfile))

jieba.set_dictionary(dictfile)
jieba.analyse.set_stop_words(stopfile)

#text = open(mdfile,"r",encoding="utf-8").read()

tags = jieba.analyse.extract_tags(lee["text"][1], topK=200)

seg_list = jieba.lcut(orgdata, cut_all=False)
dictionary = Counter(seg_list)

freq = {}
for ele in dictionary:
    if ele in tags:
        freq[ele] = dictionary[ele]
print(freq) # 計算出現的次數

wordcloud = WordCloud(background_color="white", mask=alice_mask, contour_color='steelblue', font_path= fontpath).generate_from_frequencies(freq)
plt.figure(figsize=(30,30))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
#
住': 14, '屍體': 39, '仔細': 23, '撫摸': 5, '這條': 36, '經過': 14, '冠絕': 3, '地一笑': 2, '各位': 50, '十年': 56, '探花郎': 15, '能將': 26, '入關': 4, '半個': 16, '虞二': 8, '李探花': 90, '拐子': 11, '引見': 4, '閣下': 110, '樹林': 19, '這四人': 5, '極樂': 34, '童子': 38, '門下': 19, '黃衣': 24, '我要': 46, '不動': 39, '一邊': 10, '查猛': 24, '紅衣': 7, '我還': 20, '沉著': 19, '臉道': 24, '你們': 224, '一刀': 41, '虛發': 21, '李兄': 17, '不在': 32, '考慮': 18, '時辰': 32, '遲早': 23, '酒店': 12, '酒家': 3, '回憶': 6, '欄杆': 12}

# %%
cheros_all = ""
for i in range(0,40):
    cheros_all = cheros_all + cheros["text"][i]
#cheros["text"][39]
len(cheros_all)
# Out:
# 892527

# %%
dictfile = "/Users/anderson/Desktop/Data Science/dict.txt.big"  # 字典檔
stopfile = "./stopwords_knife.txt"  # stopwords
fontpath = "/Users/anderson/Library/Group Containers/UBF8T346G9.Office/FontCache/4/CloudFonts/TTC/82731638364.ttc"  # 字型檔

#mdfile = test_tt[0]
pngfile = "./eagle2.jpeg"  # 剛才下載存的底圖

alice_mask = np.array(Image.open(pngfile))

jieba.set_dictionary(dictfile)
jieba.analyse.set_stop_words(stopfile)

#text = open(mdfile,"r",encoding="utf-8").read()

tags = jieba.analyse.extract_tags(cheros_all, topK=300)

seg_list = jieba.lcut(orgdata, cut_all=False)
dictionary = Counter(seg_list)

freq = {}
for ele in dictionary:
    if ele in tags:
        freq[ele] = dictionary[ele]
print(freq) # 計算出現的次數

wordcloud = WordCloud(background_color="white", mask=alice_mask, contour_color='steelblue', font_path= fontpath).generate_from_frequencies(freq)
plt.figure(figsize=(30,30))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Building prefix dict from /Users/anderson/Desktop/Data Science/dict.txt.big ...
# Loading model from cache /var/folders/k_/2r9gfk5j0fbc0l7wptv_v2jc0000gn/T/jieba.u52e16fc3ddadd0bb6f0fd9b070d121de.cache
# Loading model cost 1.023 seconds.
# Prefix dict has been built successfully.
# {'一個': 673, '雖然': 226, '就是': 456, '大聲': 54, '起來': 334, '臉上': 155, '這是': 131, '這人': 239, '看來': 218, '一條': 55, '卻是': 92, '終於': 129, '不知': 223, '突然': 330, '一聲': 244, '身上': 172, '自己': 714, '見到': 96, '還是': 546, '這裏': 385, '不肯': 96, '還有': 254, '沒有': 1519, '暗暗': 8, '難道': 263, '總是': 68, '知道': 1035, '這個': 50, '一陣': 101, '聲音': 208, '於是': 23, '聽到': 98, '回頭': 51, '不能': 292, '一張': 45, '的話': 151, '無法': 119, '說話': 218, '忽然': 666, '原來': 108, '不是': 419, '上來': 11, '不會': 247, '出來': 310, '東西': 83, '不見': 59, '如此': 203, '本來': 124, '不過': 262, '孩子': 133, '這次': 84, '這時': 107, '他們': 507, '進來': 100, '身後': 44, '早已': 130, '點頭': 87, '過了': 104, '回來': 97, '再說': 42, '三個': 44, '對方': 49, '之後': 42, '可是': 265, '更是': 25, '咱們': 33, '兄弟': 94, '否則': 64, '再也': 87, '兩人': 110, '不覺': 13, '不敢': 130, '輕輕': 76, '這才': 54, '兩個': 101, '下來': 112, '身子': 118, '臉色': 100, '兩位': 38, '怎樣': 40, '性命': 26, '武功': 125, '想起': 44, '無人': 12, '不禁': 79, '之上': 11, '我們': 314, '正是': 114, '一齊': 40, '過來': 85, '雙手': 62, '不可': 54, '不錯': 256, '這樣': 197, '絲毫': 33, '出去': 144, '如何': 57, '想到': 81, '出手': 223, '此時': 10, '手裏': 137, '不到': 62, '說道': 6, '許多': 40, '這位': 50, '竟是': 50, '喜歡': 109, '哪裏': 130, '這些': 122, '敵人': 10, '將他': 48, '模樣': 13, '手腕': 11, '你們': 224, '動手': 33, '時辰': 32, '肩頭': 26, '始終': 46, '轉身': 42, '功夫': 32, '遠遠': 24, '過去': 163, '右手': 27, '不住': 21, '不得': 13, '搖頭': 51, '穴道': 32, '伸手': 18, '一塊': 15, '一招': 29, '之下': 28, '問道': 71, '左手': 24, '江南': 1, '怒道': 21, '女子': 38, '一人': 59, '後來': 23, '厲害': 34, '心想': 7, '女兒': 4, '一驚': 26, '一掌': 15, '一隻': 53, '今日': 56, '兵刃': 25, '兒子': 59, '手中': 21, '哈哈大笑': 2, '當真': 19, '同時': 17, '之間': 33, '三人': 6, '抓住': 10, '功力': 4, '齊聲': 1, '大叫': 10, '言語': 4, '喝道': 15, '小子': 10, '個個': 1, '幾個': 33, '漢子': 55, '指點': 3, '弟子': 45, '背後': 22, '這一': 11, '之中': 10, '爹爹': 5, '這般': 2, '不及': 6, '受傷': 4, '父親': 39, '眼見': 9, '答應': 56, '母親': 34, '聲響': 4, '姑娘': 114, '異常': 2, '難以': 7, '一會': 2, '一時': 7, '來到': 9, '隨即': 1, '比武': 2, '一燈': 2, '地下': 5, '頭頂': 6, '之聲': 9, '侄兒': 6, '掌法': 1, '鐵掌': 3, '當下': 2, '轉頭': 5, '內功': 3, '胸口': 6, '縱身': 2, '低聲': 1, '聽得': 4, '心中': 9, '躍起': 8, '心道': 1, '幫主': 46, '二人': 1, '師父': 1, '向來': 1, '丐幫': 1, '剛才': 5, '當年': 1}

# %%
alice_mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
#暫時貼
flat = [x for sublist in subdata_seg_list for x in sublist]
diction = Counter(flat)

# %%
#暫時貼
mask = np.array(Image.open("criminal.jpg"))
font = "C:\Windows\Fonts\MSJH.TTC"

# %%
#暫時貼
wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(diction)

# %%
#暫時貼
plt.figure(figsize=(20,20))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
print("test\ahaha")
# Out:
# testhaha
